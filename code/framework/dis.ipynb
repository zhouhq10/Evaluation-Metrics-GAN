# %%
import numpy as np

# %%
#cele mix ratio from 0 to 1
score = []
s0 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cele_discriminability\\mix\\mix_celeba_resnet34_conv_celeba_true_test_1.00_1_0_2000_0', allow_pickle=True)
score.append(s0)

for i in np.arange(0.1, 1.0, 0.1):
    path = 'D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cele_discriminability\\mix\\'
    fpath = path+'mix_celeba_resnet34_conv_celeba_true_test_'+('%.2f' % (1-i))+'_1_0_celeba_DCGAN49_'+('%.2f' % i) +'_1_0_2000_0'
    score.append(np.load(fpath, allow_pickle=True))

s10 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cele_discriminability\\mix\\mix_celeba_resnet34_conv_celeba_DCGAN49_1.00_1_0_2000_0', allow_pickle=True)
score.append(s10)

# %%
x = np.arange(0.0, 1.1, 0.1)

# %%
emd = []
for i in range(11):
    emd.append(score[i].emd)
emd = np.array(emd)
emd = emd/emd[-1]

mmd = []
for i in range(11):
    mmd.append(score[i].mmd)
mmd = np.array(mmd)
mmd = mmd/mmd[-1]

knnacc = []
knnreal = []
knnfake = []
for i in range(11):
    knnacc.append(score[i].knn.acc)
    knnreal.append(score[i].knn.acc_t)
    knnfake.append(score[i].knn.acc_f)
knnacc = np.array(knnacc)
knnreal = np.array(knnreal)
knnfake = np.array(knnfake)
knnacc = knnacc/knnacc[-1]

# %%
score[0].knn

# %%
incep = []
in0 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cele_discriminability\\incep\\incep_celeba_resnet34_smax_celeba_true_test_1.00_1_0_2000_1', allow_pickle=True)
incep.append(in0)

for i in np.arange(0.1, 1.0, 0.1):
    path = 'D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cele_discriminability\\incep\\'
    fpath = path+'incep_celeba_resnet34_smax_celeba_true_test_'+('%.2f' % (1-i))+'_1_0_celeba_DCGAN49_'+('%.2f' % i) +'_1_0_2000_1'
    incep.append(np.load(fpath, allow_pickle=True))

in10 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cele_discriminability\\incep\\incep_celeba_resnet34_smax_celeba_DCGAN49_1.00_1_0_2000_1', allow_pickle=True)
incep.append(in10)
incep = np.array(incep)
incep = 1-incep/incep[0]

# %%
mode = []
mo0 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cele_discriminability\\mode\\mode_score_celeba_resnet34_smax_celeba_true_test_1.00_1_0_2000_1', allow_pickle=True)
mode.append(mo0)

for i in np.arange(0.1, 1.0, 0.1):
    path = 'D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cele_discriminability\\mode\\'
    fpath = path+'mode_score_celeba_resnet34_smax_celeba_true_test_'+('%.2f' % (1-i))+'_1_0_celeba_DCGAN49_'+('%.2f' % i) +'_1_0_2000_1'
    mode.append(np.load(fpath, allow_pickle=True))

mo10 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cele_discriminability\\mode\\mode_score_celeba_resnet34_smax_celeba_DCGAN49_1.00_1_0_2000_1', allow_pickle=True)
mode.append(mo10)
mode = np.array(mode)
mode = 1-mode/mode[0]

# %%
fid = []
fi0 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cele_discriminability\\fid\\fid_celeba_resnet34_smax_celeba_true_test_1.00_1_0_2000_0', allow_pickle=True)
fid.append(fi0)

for i in np.arange(0.1, 1.0, 0.1):
    path = 'D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cele_discriminability\\fid\\'
    fpath = path+'fid_celeba_resnet34_smax_celeba_true_test_'+('%.2f' % (1-i))+'_1_0_celeba_DCGAN49_'+('%.2f' % i) +'_1_0_2000_0'
    fid.append(np.load(fpath, allow_pickle=True))

fi10 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cele_discriminability\\fid\\fid_celeba_resnet34_smax_celeba_DCGAN49_1.00_1_0_2000_0', allow_pickle=True)
fid.append(fi10)
fid = np.array(fid)
fid = fid/fid[-1]

# %%
import matplotlib.pyplot as plt

#plt.figure(figsize=(8,12))

l1 = plt.plot(x, emd, '*-')
l2 = plt.plot(x,mmd, '*-')
l3 = plt.plot(x,knnacc, '*-')
l4 = plt.plot(x,incep, '*-')
l5 = plt.plot(x,mode, '*-')
l6 = plt.plot(x,fid, '*-')

plt.title('celeba')
plt.legend([l1,l2,l3,l4,l5,l6], labels=['EMD', 'MMD', 'KNN_ACC', 'Inception Score', 'Mode Score','FID'], loc = 'middle left',fontsize=8)
plt.xlabel('ratio of fake images in mix')
plt.savefig('cele_dis')

# %%
#######################cifar########################

# %%
#cifar mix ratio from 0 to 1
score2 = []
s02 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cifar_discriminability\\mix\\mix_cifar10_resnet34_conv_cifar10_true_test_1.00_1_0_2000_0', allow_pickle=True)
score2.append(s02)

for i in np.arange(0.1, 1.0, 0.1):
    path = 'D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cifar_discriminability\\mix\\'
    fpath = path+'mix_cifar10_resnet34_conv_cifar10_true_test_'+('%.2f' % (1-i))+'_1_0_cifar10_DCGAN49_'+('%.2f' % i) +'_1_0_2000_0'
    score2.append(np.load(fpath, allow_pickle=True))

s102 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cifar_discriminability\\mix\\mix_cifar10_resnet34_conv_cifar10_DCGAN49_1.00_1_0_2000_0', allow_pickle=True)
score2.append(s102)

# %%
emd = []
for i in range(11):
    emd.append(score2[i].emd)
emd = np.array(emd)
emd = emd/emd[-1]

mmd = []
for i in range(11):
    mmd.append(score2[i].mmd)
mmd = np.array(mmd)
mmd = mmd/mmd[-1]

knnreal = []
knnfake = []
knnacc = []
for i in range(11):
    knnreal.append(score2[i].knn.acc_t)
    knnfake.append(score2[i].knn.acc_f)
    knnacc.append(score2[i].knn.acc)
knnreal = np.array(knnreal)
knnfake = np.array(knnfake)
knnacc = np.array(knnacc)
knnacc = knnacc/knnacc[-1]

# %%
incep = []
in0 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cifar_discriminability\\incep\\incep_cifar10_resnet34_smax_cifar10_true_test_1.00_1_0_2000_0', allow_pickle=True)
incep.append(in0)

for i in np.arange(0.1, 1.0, 0.1):
    path = 'D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cifar_discriminability\\incep\\'
    fpath = path+'incep_cifar10_resnet34_smax_cifar10_true_test_'+('%.2f' % (1-i))+'_1_0_cifar10_DCGAN49_'+('%.2f' % i) +'_1_0_2000_0'
    incep.append(np.load(fpath, allow_pickle=True))

in10 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cifar_discriminability\\incep\\incep_cifar10_resnet34_smax_cifar10_DCGAN49_1.00_1_0_2000_0', allow_pickle=True)
incep.append(in10)
incep = np.array(incep)
incep = 1 - incep/incep[0]
################################################################################################
mode = []
mo0 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cifar_discriminability\\mode\\mode_score_cifar10_resnet34_smax_cifar10_true_test_1.00_1_0_2000_0', allow_pickle=True)
mode.append(mo0)

for i in np.arange(0.1, 1.0, 0.1):
    path = 'D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cifar_discriminability\\mode\\'
    fpath = path+'mode_score_cifar10_resnet34_smax_cifar10_true_test_'+('%.2f' % (1-i))+'_1_0_cifar10_DCGAN49_'+('%.2f' % i) +'_1_0_2000_0'
    mode.append(np.load(fpath, allow_pickle=True))

mo10 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cifar_discriminability\\mode\\mode_score_cifar10_resnet34_smax_cifar10_DCGAN49_1.00_1_0_2000_0', allow_pickle=True)
mode.append(mo10)
mode = np.array(mode)
mode = 1-mode/mode[0]
################################################################################################
fid = []
fi0 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cifar_discriminability\\fid\\fid_cifar10_resnet34_smax_cifar10_true_test_1.00_1_0_2000_0', allow_pickle=True)
fid.append(fi0)

for i in np.arange(0.1, 1.0, 0.1):
    path = 'D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cifar_discriminability\\fid\\'
    fpath = path+'fid_cifar10_resnet34_smax_cifar10_true_test_'+('%.2f' % (1-i))+'_1_0_cifar10_DCGAN49_'+('%.2f' % i) +'_1_0_2000_0'
    fid.append(np.load(fpath, allow_pickle=True))

fi10 = np.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\cifar_discriminability\\fid\\fid_cifar10_resnet34_smax_cifar10_DCGAN49_1.00_1_0_2000_0', allow_pickle=True)
fid.append(fi10)
fid = np.array(fid)
fid = fid/fid[-1]

# %%
import matplotlib.pyplot as plt

l1 = plt.plot(x, emd, '*-')
l2 = plt.plot(x,mmd, '*-')
l3 = plt.plot(x,knnacc, '*-')
l4 = plt.plot(x,incep, '*-')
l5 = plt.plot(x,mode, '*-')
l6 = plt.plot(x,fid, '*-')


plt.legend([l1,l2,l3,l4,l5,l6], labels=['EMD', 'MMD', 'KNN_ACC', 'Inception Score', 'Mode Score','FID'], loc = 'lower right',fontsize=8)
plt.xlabel('ratio of fake images in mix')
plt.title('cifar10')
plt.savefig('cifar_dis')

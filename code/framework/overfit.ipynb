# %%
#collapse
import torch
import numpy as np
import matplotlib.pyplot as plt
co = torch.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\repo\\rlt\\overfit\\celeba_scores_1.pth')
x = np.arange(0.0,1.1,0.1)

# %%
emd = co[1][:, 0]
mmd = co[1][:, 1]
knnreal = co[1][:, 2]
knnfake = co[1][:, 3]

# %%
incep = co[2][:, 0]
mode = co[2][:, 1]
fid = co[2][:, 2]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,12))

plt.subplot(511)
l1 = plt.plot(x, emd, '*-')
#plt.ylim(9, 12)
plt.legend(l1, labels=['EMD'], loc = 'upper center')

plt.subplot(512)
l2 = plt.plot(x,mmd, '*-')
#plt.ylim(0.3, 0.45)
plt.legend(l2, labels=['MMD'], loc = 'upper center')

plt.subplot(513)
l31 = plt.plot(x,knnreal, '*-')
l32 = plt.plot(x,knnfake, '*-')
#plt.ylim(0, 1)
plt.legend([l31, l32], labels=['KNN_real','KNN_fake'], loc = 'upper center')

plt.subplot(514)
l6 = plt.plot(x,fid, '*-')
#plt.ylim(0.01, 0.14)
plt.legend(l6, labels=['FID'], loc = 'upper center')

plt.subplot(515)
l4 = plt.plot(x,incep, '*-')
l5 = plt.plot(x,mode, '*-')
#plt.ylim(1.15, 1.35)
plt.legend([l4,l5], labels=['Inception Score', 'Mode Score'], loc = 'upper center')

plt.savefig('over_ce')

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
co = torch.load('D:\\google\\gan_proj\\framework\\zhq\\new_gan_exp\\repo\\rlt\\overfit\\cifar10_scores_1.pth')
x = np.arange(0.0, 1.1, 0.1)

emd = co[1][:, 0]
mmd = co[1][:, 1]
knnreal = co[1][:, 2]
knnfake = co[1][:, 3]

incep = co[2][:, 0]
mode = co[2][:, 1]
fid = co[2][:, 2]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,12))

plt.subplot(511)
l1 = plt.plot(x, emd, '*-')
#plt.ylim(9, 12)
plt.legend(l1, labels=['EMD'], loc = 'upper center')

plt.subplot(512)
l2 = plt.plot(x,mmd, '*-')
#plt.ylim(0.3, 0.45)
plt.legend(l2, labels=['MMD'], loc = 'upper center')

plt.subplot(513)
l31 = plt.plot(x,knnreal, '*-')
l32 = plt.plot(x,knnfake, '*-')
#plt.ylim(0, 1)
plt.legend([l31, l32], labels=['KNN_real','KNN_fake'], loc = 'upper center')

plt.subplot(514)
l6 = plt.plot(x,fid, '*-')
#plt.ylim(0.01, 0.14)
plt.legend(l6, labels=['FID'], loc = 'upper center')

plt.subplot(515)
l4 = plt.plot(x,incep, '*-')
l5 = plt.plot(x,mode, '*-')
#plt.ylim(1.15, 1.35)
plt.legend([l4,l5], labels=['Inception Score', 'Mode Score'], loc = 'upper center')

plt.savefig('over_ci')
